# %% [markdown]
# # Running the QRF Model
#
#
#     The model is based off the paper Srikumar et al., "A kernel-based quantum random forest for improved classification", (2022).
#     The code is run on a dataset that is used to predict for heart diseases

# %%
from quantum_random_forest import QuantumRandomForest, set_multiprocessing
from split_function import SplitCriterion
from data_construction import data_preprocessing
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics, datasets

# %% [markdown]
# ## Load dataset
#
# Here you can load your own dataset. The preprocessing can be left untouched. However, it is important to note that certain embeddings require data of certain dimension. PCA reduction to the required dimension can be achieved by changing the X_dim variable.

# %%
import pandas as pd

data = pd.read_csv('heart.csv')
num_classes = 2
X = data.drop(columns='output')
y = data['output']

# %% [markdown]
# ### Data pre-processing

# %%
training_set, testing_set = data_preprocessing(X, y, 
                                               train_prop=0.75,        # Proportion of dataset allocated for training
                                               X_dim=6)                # Determine the required dimension of the dataset. None for default.
# Out:
# New datapoint dimension: 6

# %% [markdown]
# ## Model parameters

# %%
n_qubits = 6                                         # Number of qubits for the embedding
dt_type = 'qke'                                      # Do not touch
ensemble_var = None                                  # Do not touch
branch_var = ['eff_anz_pqc_arch', 
              'iqp_anz_pqc_arch', 
              'eff_anz_pqc_arch']                    # Type of Anzatz, or as a list for different down the tree - as given 
num_trees = 100                                        # Number of trees in ensemble 
split_num = 2                                        # Do not touch
pqc_sample_num = 2024                                # Number of circuit samples per kernel estimation
num_classes = num_classes                            # Number of classes in dataset
max_depth = 4                                        # Maximum depth of the tree
num_params_split = n_qubits*(n_qubits +1)            # Number of parameters in the embedding (different for different anzatz), list for different down the tree [2 * n_qubits ** 2 , n_qubits*(n_qubits +1), 2 * n_qubits ** 2]
num_rand_gen = 1                                     # Do not touch
num_rand_meas_q = n_qubits                           # Do not touch 
svm_num_train = 5                                    # L, Number of Landmarks
svm_c = 10                                           # C term in SVM optimisation, or list down the tree [100, 50, 20]
min_samples_split = svm_num_train                    # Minimum number of samples
embedding_type = ['as_params_all', 
                  'as_params_iqp', 
                  'as_params_all']                   # Type of embedding, or as a list - as given
criterion = SplitCriterion.init_info_gain('clas')    # Do not touch
device = 'cirq'                                      # Choose a device. Also possible to run on IBM

# %% [markdown]
# ## Set up model

# %%
qrf = QuantumRandomForest(n_qubits, 'clas', num_trees, criterion, max_depth=max_depth, 
                          min_samples_split=min_samples_split, tree_split_num=split_num, num_rand_meas_q=num_rand_meas_q,
                          ensemble_var=ensemble_var, dt_type=dt_type, num_classes=num_classes, ensemble_vote_type='ave',
                          num_params_split=num_params_split, num_rand_gen=num_rand_gen, pqc_sample_num=pqc_sample_num,
                          embed=embedding_type, branch_var=branch_var, svm_num_train=svm_num_train, svm_c=svm_c, 
                          nystrom_approx=True, device=device)

# %% [markdown]
# ## Train

# %%
cores = 3
set_multiprocessing(True, cores)                   # Set to False if you don't want parallel computation
qrf.train(training_set, 
          partition_sample_size=180)               # Partition size is the number of instances given to each tree. Set to None to use all the data for all trees

# %% [markdown]
# ## Test

# %%
acc, preds_qrf = qrf.test(testing_set, 
                          ret_pred=True, 
                          parallel=False,            # Set to False if you don't want parallel computation. Needs to be False for calc_tree_corr to be True.
                          calc_tree_corr=True)       # True is required to later look at correlations between trees
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.66it/s]
# 100%|██████████| 5/5 [00:00<00:00,  6.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.75it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.20it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.19it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 20.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.47it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.23it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.78it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.93it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.30it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.79it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.81it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.94it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.18it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.67it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.21it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.08it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.61it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.76it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.63it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.69it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.53it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.92it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.28it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.24it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.25it/s]
# 100%|██████████| 5/5 [00:00<00:00,  8.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.42it/s]
# 100%|██████████| 5/5 [00:02<00:00,  1.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 43.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.05it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.05it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]it]
# 100%|██████████| 5/5 [00:00<00:00, 14.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 63.65it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.11it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.11it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.61it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.52it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 63.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.05it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]it]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.09it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 43.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.11it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.71it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.09it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 16.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.68it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.99it/s]it]
# 100%|██████████| 5/5 [00:00<00:00, 12.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 53.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 18.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.95it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 45.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 37.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.51it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.84it/s]
# 100%|██████████| 5/5 [00:00<00:00, 40.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 17.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.92it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.31it/s]
# ...
# 100%|██████████| 5/5 [00:00<00:00, 14.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.16it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 44.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.52it/s]s/it]
# 100%|██████████| 5/5 [00:00<00:00, 11.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 49.57it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.05it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.19it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.91it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 15.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 39.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.94it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.18it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.82it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.69it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.08it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.62it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.76it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.75it/s]
# 100%|██████████| 5/5 [00:00<00:00, 19.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.16it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.44it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.58it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.53it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.79it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 35.41it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.63it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.74it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.32it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.49it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.09it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.16it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.39it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.90it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.35it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.42it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.01it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.61it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.93it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.54it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.48it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 30.36it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 34.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.08it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.29it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.98it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.87it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.21it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.13it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.47it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.45it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.65it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.24it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.22it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.04it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.72it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.15it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.89it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.77it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.08it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.65it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.10it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.59it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.56it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.00it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.38it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.70it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.85it/s]
# 100%|██████████| 5/5 [00:00<00:00, 33.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.43it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.33it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.31it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.17it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.33it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.12it/s]
# 100%|██████████| 5/5 [00:00<00:00, 23.46it/s]
# 100%|██████████| 5/5 [00:00<00:00, 32.18it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.34it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.55it/s]
# 100%|██████████| 5/5 [00:00<00:00, 22.46it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.83it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.78it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.88it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.27it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.40it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.37it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 21.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 10.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 26.07it/s]
# 100%|██████████| 5/5 [00:00<00:00, 28.20it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.02it/s]
# 100%|██████████| 5/5 [00:00<00:00, 29.28it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.09it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.81it/s]
# 100%|██████████| 5/5 [00:00<00:00, 31.64it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.06it/s]
# 100%|██████████| 5/5 [00:00<00:00, 14.50it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.25it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.82it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 24.67it/s]
# 100%|██████████| 5/5 [00:00<00:00, 25.99it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.23it/s]
# 100%|██████████| 5/5 [00:00<00:00, 27.81it/s]
# 100%|██████████| 76/76 [1:54:06<00:00, 90.08s/it]

# %%
# Classification report
print(f"Classification report for QRF:\n"
      f"{metrics.classification_report(testing_set.y, preds_qrf)}\n")
# Out:
# Classification report for QRF:
#               precision    recall  f1-score   support
#
#            0       0.83      0.69      0.75        35
#            1       0.77      0.88      0.82        41
#
#     accuracy                           0.79        76
#    macro avg       0.80      0.78      0.78        76
# weighted avg       0.79      0.79      0.79        76

# %% [markdown]
# ## Further analysis of model

# %%
# Print out tree
qrf.print_trees()
# Out:
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 165 instances
#    |  |- () - 27 instances
#    |  |  |- ({0: 0.91, 1: 0.09}) - 23 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#    |  `- () - 138 instances
#    |     |- ({0: 0.36, 1: 0.64}) - 137 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 15 instances
#       |- () - 14 instances
#       |  |- ({0: 0.85, 1: 0.15}) - 13 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 72 instances
#    |  |- () - 71 instances
#    |  |  |- ({0: 0.23, 1: 0.77}) - 71 instances
#    |  |  `- ({0: 0.23, 1: 0.77}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 108 instances
#       |- () - 107 instances
#       |  |- ({0: 0.61, 1: 0.39}) - 102 instances
#       |  `- ({0: 0.4, 1: 0.6}) - 5 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 77 instances
#    |  |- () - 75 instances
#    |  |  |- ({0: 0.18, 1: 0.82}) - 74 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 103 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 102 instances
#          |- ({0: 0.0, 1: 1.0}) - 4 instances
#          `- ({0: 0.64, 1: 0.36}) - 98 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 135 instances
#    |  |- () - 134 instances
#    |  |  |- ({0: 0.8, 1: 0.2}) - 5 instances
#    |  |  `- ({0: 0.31, 1: 0.69}) - 129 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 45 instances
#       |- () - 44 instances
#       |  |- ({0: 0.79, 1: 0.21}) - 43 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 28 instances
#    |  |- () - 23 instances
#    |  |  |- ({0: 0.91, 1: 0.09}) - 22 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 5 instances
#    `- () - 152 instances
#       |- () - 137 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#       |  `- ({0: 0.29, 1: 0.71}) - 136 instances
#       `- () - 15 instances
#          |- ({0: 0.93, 1: 0.07}) - 14 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 140 instances
#    |  |- () - 93 instances
#    |  |  |- ({0: 0.66, 1: 0.34}) - 85 instances
#    |  |  `- ({0: 0.25, 1: 0.75}) - 8 instances
#    |  `- () - 47 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 4 instances
#    |     `- ({0: 0.37, 1: 0.63}) - 43 instances
#    `- () - 40 instances
#       |- () - 37 instances
#       |  |- ({0: 0.67, 1: 0.33}) - 6 instances
#       |  `- ({0: 0.13, 1: 0.87}) - 31 instances
#       `- ({0: 0.67, 1: 0.33}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 159 instances
#    |  |- () - 158 instances
#    |  |  |- ({0: 0.75, 1: 0.25}) - 4 instances
#    |  |  `- ({0: 0.36, 1: 0.64}) - 154 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 21 instances
#       |- ({0: 0.5, 1: 0.5}) - 4 instances
#       `- () - 17 instances
#          |- ({0: 0.88, 1: 0.12}) - 16 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 42 instances
#    |  |- () - 41 instances
#    |  |  |- ({0: 0.9, 1: 0.1}) - 40 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 138 instances
#       |- () - 11 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 10 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 127 instances
#          |- ({0: 0.28, 1: 0.72}) - 125 instances
#          `- ({0: 1.0, 1: 0.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 134 instances
#    |  |- () - 10 instances
#    |  |  |- ({0: 0.9, 1: 0.1}) - 10 instances
#    |  |  `- ({0: 0.9, 1: 0.1}) - 0 instances
#    |  `- () - 124 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 5 instances
#    |     `- ({0: 0.3, 1: 0.7}) - 119 instances
#    `- () - 46 instances
#       |- () - 44 instances
#       |  |- ({0: 0.74, 1: 0.26}) - 43 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.5, 1: 0.5}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 105 instances
#    |  |- () - 101 instances
#    |  |  |- ({0: 0.17, 1: 0.83}) - 6 instances
#    |  |  `- ({0: 0.68, 1: 0.32}) - 95 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#    `- () - 75 instances
#       |- () - 74 instances
#       |  |- ({0: 0.16, 1: 0.84}) - 74 instances
#       |  `- ({0: 0.16, 1: 0.84}) - 0 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 168 instances
#    |  |- () - 28 instances
#    |  |  |- ({0: 0.4, 1: 0.6}) - 5 instances
#    |  |  `- ({0: 0.83, 1: 0.17}) - 23 instances
#    |  `- () - 140 instances
#    |     |- ({0: 0.33, 1: 0.67}) - 138 instances
#    |     `- ({0: 0.5, 1: 0.5}) - 2 instances
#    `- () - 12 instances
#       |- ({0: 1.0, 1: 0.0}) - 11 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 132 instances
#    |  |- () - 11 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 10 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 121 instances
#    |     |- ({0: 0.31, 1: 0.69}) - 120 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 48 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 47 instances
#          |- ({0: 0.72, 1: 0.28}) - 47 instances
#          `- ({0: 0.72, 1: 0.28}) - 0 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 43 instances
#    |  |- () - 41 instances
#    |  |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  |  `- ({0: 0.7, 1: 0.3}) - 40 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    `- () - 137 instances
#       |- () - 111 instances
#       |  |- ({0: 0.5, 1: 0.5}) - 2 instances
#       |  `- ({0: 0.38, 1: 0.62}) - 109 instances
#       `- () - 26 instances
#          |- ({0: 0.21, 1: 0.79}) - 14 instances
#          `- ({0: 1.0, 1: 0.0}) - 12 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 141 instances
#    |  |- () - 133 instances
#    |  |  |- ({0: 0.36, 1: 0.64}) - 130 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 3 instances
#    |  `- () - 8 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |     `- ({0: 0.83, 1: 0.17}) - 6 instances
#    `- () - 39 instances
#       |- () - 37 instances
#       |  |- ({0: 0.82, 1: 0.18}) - 28 instances
#       |  `- ({0: 0.33, 1: 0.67}) - 9 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 71 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 70 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |     `- ({0: 0.23, 1: 0.77}) - 69 instances
#    `- () - 109 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 108 instances
#          |- ({0: 0.61, 1: 0.39}) - 101 instances
#          `- ({0: 0.29, 1: 0.71}) - 7 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 26 instances
#    |  |- () - 25 instances
#    |  |  |- ({0: 0.92, 1: 0.08}) - 24 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 154 instances
#       |- ({0: 1.0, 1: 0.0}) - 2 instances
#       `- () - 152 instances
#          |- ({0: 0.33, 1: 0.67}) - 132 instances
#          `- ({0: 0.8, 1: 0.2}) - 20 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 48 instances
#    |  |- () - 47 instances
#    |  |  |- ({0: 0.89, 1: 0.11}) - 47 instances
#    |  |  `- ({0: 0.89, 1: 0.11}) - 0 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 132 instances
#       |- () - 131 instances
#       |  |- ({0: 0.28, 1: 0.72}) - 129 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 15 instances
#    |  |- () - 14 instances
#    |  |  |- ({0: 0.77, 1: 0.23}) - 13 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 165 instances
#       |- () - 37 instances
#       |  |- ({0: 0.76, 1: 0.24}) - 33 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#       `- () - 128 instances
#          |- ({0: 0.83, 1: 0.17}) - 6 instances
#          `- ({0: 0.34, 1: 0.66}) - 122 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 10 instances
#    |  |- () - 8 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 7 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    `- () - 170 instances
#       |- () - 154 instances
#       |  |- ({0: 0.65, 1: 0.35}) - 34 instances
#       |  `- ({0: 0.34, 1: 0.66}) - 120 instances
#       `- () - 16 instances
#          |- ({0: 0.73, 1: 0.27}) - 15 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 148 instances
#    |  |- () - 147 instances
#    |  |  |- ({0: 0.37, 1: 0.63}) - 145 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 32 instances
#       |- () - 31 instances
#       |  |- ({0: 0.86, 1: 0.14}) - 29 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 163 instances
#    |  |- () - 27 instances
#    |  |  |- ({0: 0.8, 1: 0.2}) - 25 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- () - 136 instances
#    |     |- ({0: 0.36, 1: 0.64}) - 135 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 17 instances
#       |- () - 12 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 11 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 5 instances
#          |- ({0: 0.0, 1: 1.0}) - 4 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 45 instances
#    |  |- ({0: 0.25, 1: 0.75}) - 4 instances
#    |  `- () - 41 instances
#    |     |- ({0: 0.33, 1: 0.67}) - 6 instances
#    |     `- ({0: 0.74, 1: 0.26}) - 35 instances
#    `- () - 135 instances
#       |- () - 6 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 4 instances
#       `- () - 129 instances
#          |- ({0: 0.31, 1: 0.69}) - 118 instances
#          `- ({0: 0.91, 1: 0.09}) - 11 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 87 instances
#    |  |- () - 86 instances
#    |  |  |- ({0: 0.0, 1: 1.0}) - 5 instances
#    |  |  `- ({0: 0.62, 1: 0.38}) - 81 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 93 instances
#       |- () - 89 instances
#       |  |- ({0: 0.25, 1: 0.75}) - 88 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#       `- ({0: 1.0, 1: 0.0}) - 4 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 142 instances
#    |  |- () - 5 instances
#    |  |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  |  `- ({0: 0.75, 1: 0.25}) - 4 instances
#    |  `- () - 137 instances
#    |     |- ({0: 0.36, 1: 0.64}) - 118 instances
#    |     `- ({0: 0.74, 1: 0.26}) - 19 instances
#    `- () - 38 instances
#       |- () - 30 instances
#       |  |- ({0: 0.97, 1: 0.03}) - 29 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 8 instances
#          |- ({0: 0.0, 1: 1.0}) - 7 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 151 instances
#    |  |- () - 144 instances
#    |  |  |- ({0: 0.32, 1: 0.68}) - 142 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- () - 7 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 6 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 29 instances
#       |- () - 28 instances
#       |  |- ({0: 0.86, 1: 0.14}) - 28 instances
#       |  `- ({0: 0.86, 1: 0.14}) - 0 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 162 instances
#    |  |- () - 160 instances
#    |  |  |- ({0: 0.38, 1: 0.62}) - 155 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 5 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 18 instances
#       |- ({0: 1.0, 1: 0.0}) - 16 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 146 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 3 instances
#    |  `- () - 143 instances
#    |     |- ({0: 0.4, 1: 0.6}) - 140 instances
#    |     `- ({0: 0.33, 1: 0.67}) - 3 instances
#    `- () - 34 instances
#       |- ({0: 0.0, 1: 1.0}) - 4 instances
#       `- () - 30 instances
#          |- ({0: 0.81, 1: 0.19}) - 27 instances
#          `- ({0: 0.33, 1: 0.67}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 162 instances
#    |  |- () - 146 instances
#    |  |  |- ({0: 0.83, 1: 0.17}) - 12 instances
#    |  |  `- ({0: 0.35, 1: 0.65}) - 134 instances
#    |  `- () - 16 instances
#    |     |- ({0: 0.92, 1: 0.08}) - 13 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 3 instances
#    `- () - 18 instances
#       |- () - 16 instances
#       |  |- ({0: 0.93, 1: 0.07}) - 15 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 97 instances
#    |  |- () - 94 instances
#    |  |  |- ({0: 0.17, 1: 0.83}) - 6 instances
#    |  |  `- ({0: 0.66, 1: 0.34}) - 88 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 3 instances
#    `- () - 83 instances
#       |- () - 83 instances
#       |  |- ({0: 0.24, 1: 0.76}) - 0 instances
#       |  `- ({0: 0.24, 1: 0.76}) - 83 instances
#       `- ({0: 0.24, 1: 0.76}) - 0 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 71 instances
#    |  |- () - 59 instances
#    |  |  |- ({0: 0.15, 1: 0.85}) - 59 instances
#    |  |  `- ({0: 0.15, 1: 0.85}) - 0 instances
#    |  `- () - 12 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 3 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 9 instances
#    `- () - 109 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 108 instances
#          |- ({0: 0.62, 1: 0.38}) - 106 instances
#          `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- ({0: 0.5, 1: 0.5}) - 2 instances
#    `- () - 178 instances
#       |- () - 10 instances
#       |  |- ({0: 0.8, 1: 0.2}) - 10 instances
#       |  `- ({0: 0.8, 1: 0.2}) - 0 instances
#       `- () - 168 instances
#          |- ({0: 0.33, 1: 0.67}) - 140 instances
#          `- ({0: 0.79, 1: 0.21}) - 28 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 137 instances
#    |  |- () - 135 instances
#    |  |  |- ({0: 0.33, 1: 0.67}) - 134 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 43 instances
#       |- () - 42 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#       |  `- ({0: 0.9, 1: 0.1}) - 41 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 26 instances
#    |  |- ({0: 0.25, 1: 0.75}) - 4 instances
#    |  `- () - 22 instances
#    |     |- ({0: 0.9, 1: 0.1}) - 21 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 154 instances
#       |- () - 145 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 3 instances
#       |  `- ({0: 0.36, 1: 0.64}) - 142 instances
#       `- () - 9 instances
#          |- ({0: 1.0, 1: 0.0}) - 6 instances
#          `- ({0: 0.33, 1: 0.67}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 63 instances
#    |  |- () - 59 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  |  `- ({0: 0.14, 1: 0.86}) - 58 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 4 instances
#    `- () - 117 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 116 instances
#          |- ({0: 0.65, 1: 0.35}) - 113 instances
#          `- ({0: 0.0, 1: 1.0}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 128 instances
#    |  |- () - 127 instances
#    |  |  |- ({0: 0.29, 1: 0.71}) - 112 instances
#    |  |  `- ({0: 0.73, 1: 0.27}) - 15 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 52 instances
#       |- () - 49 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 3 instances
#       |  `- ({0: 0.83, 1: 0.17}) - 46 instances
#       `- ({0: 0.0, 1: 1.0}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 176 instances
#    |  |- () - 175 instances
#    |  |  |- ({0: 0.38, 1: 0.62}) - 162 instances
#    |  |  `- ({0: 0.85, 1: 0.15}) - 13 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- ({0: 0.5, 1: 0.5}) - 4 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 66 instances
#    |  |- () - 63 instances
#    |  |  |- ({0: 0.14, 1: 0.86}) - 63 instances
#    |  |  `- ({0: 0.14, 1: 0.86}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 3 instances
#    `- () - 114 instances
#       |- () - 112 instances
#       |  |- ({0: 0.25, 1: 0.75}) - 8 instances
#       |  `- ({0: 0.63, 1: 0.37}) - 104 instances
#       `- ({0: 0.5, 1: 0.5}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 149 instances
#    |  |- () - 147 instances
#    |  |  |- ({0: 0.5, 1: 0.5}) - 2 instances
#    |  |  `- ({0: 0.36, 1: 0.64}) - 145 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 31 instances
#       |- () - 30 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 26 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 125 instances
#    |  |- () - 105 instances
#    |  |  |- ({0: 0.68, 1: 0.32}) - 98 instances
#    |  |  `- ({0: 0.14, 1: 0.86}) - 7 instances
#    |  `- () - 20 instances
#    |     |- ({0: 0.18, 1: 0.82}) - 17 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 3 instances
#    `- () - 55 instances
#       |- () - 54 instances
#       |  |- ({0: 0.17, 1: 0.83}) - 52 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- ({0: 1.0, 1: 0.0}) - 3 instances
#    `- () - 177 instances
#       |- () - 25 instances
#       |  |- ({0: 0.95, 1: 0.05}) - 19 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 6 instances
#       `- () - 152 instances
#          |- ({0: 0.71, 1: 0.29}) - 21 instances
#          `- ({0: 0.32, 1: 0.68}) - 131 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 169 instances
#    |  |- () - 164 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  |  `- ({0: 0.42, 1: 0.58}) - 163 instances
#    |  `- () - 5 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 4 instances
#    `- () - 11 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 10 instances
#          |- ({0: 1.0, 1: 0.0}) - 8 instances
#          `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 162 instances
#    |  |- () - 160 instances
#    |  |  |- ({0: 0.32, 1: 0.68}) - 136 instances
#    |  |  `- ({0: 0.79, 1: 0.21}) - 24 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 18 instances
#       |- () - 17 instances
#       |  |- ({0: 0.88, 1: 0.12}) - 16 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 78 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 77 instances
#    |     |- ({0: 0.21, 1: 0.79}) - 75 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 102 instances
#       |- () - 100 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 4 instances
#       |  `- ({0: 0.7, 1: 0.3}) - 96 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 79 instances
#    |  |- () - 11 instances
#    |  |  |- ({0: 0.89, 1: 0.11}) - 9 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- () - 68 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 2 instances
#    |     `- ({0: 0.18, 1: 0.82}) - 66 instances
#    `- () - 101 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 100 instances
#          |- ({0: 0.64, 1: 0.36}) - 99 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 44 instances
#    |  |- () - 43 instances
#    |  |  |- ({0: 0.74, 1: 0.26}) - 39 instances
#    |  |  `- ({0: 0.25, 1: 0.75}) - 4 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 136 instances
#       |- () - 134 instances
#       |  |- ({0: 0.36, 1: 0.64}) - 129 instances
#       |  `- ({0: 0.8, 1: 0.2}) - 5 instances
#       `- ({0: 1.0, 1: 0.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 19 instances
#    |  |- () - 18 instances
#    |  |  |- ({0: 0.81, 1: 0.19}) - 16 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 161 instances
#       |- () - 157 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 5 instances
#       |  `- ({0: 0.39, 1: 0.61}) - 152 instances
#       `- ({0: 0.75, 1: 0.25}) - 4 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 55 instances
#    |  |- () - 53 instances
#    |  |  |- ({0: 0.17, 1: 0.83}) - 53 instances
#    |  |  `- ({0: 0.17, 1: 0.83}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 125 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 124 instances
#          |- ({0: 0.62, 1: 0.38}) - 117 instances
#          `- ({0: 0.14, 1: 0.86}) - 7 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 147 instances
#    |  |- () - 146 instances
#    |  |  |- ({0: 0.33, 1: 0.67}) - 129 instances
#    |  |  `- ({0: 0.94, 1: 0.06}) - 17 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 33 instances
#       |- () - 30 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#       |  `- ({0: 0.89, 1: 0.11}) - 28 instances
#       `- ({0: 0.33, 1: 0.67}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 65 instances
#    |  |- () - 63 instances
#    |  |  |- ({0: 0.24, 1: 0.76}) - 62 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 115 instances
#       |- () - 9 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 8 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#       `- () - 106 instances
#          |- ({0: 0.66, 1: 0.34}) - 94 instances
#          `- ({0: 0.42, 1: 0.58}) - 12 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 69 instances
#    |  |- () - 68 instances
#    |  |  |- ({0: 0.18, 1: 0.82}) - 68 instances
#    |  |  `- ({0: 0.18, 1: 0.82}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 111 instances
#       |- ({0: 0.0, 1: 1.0}) - 2 instances
#       `- () - 109 instances
#          |- ({0: 0.0, 1: 1.0}) - 10 instances
#          `- ({0: 0.7, 1: 0.3}) - 99 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 117 instances
#    |  |- () - 112 instances
#    |  |  |- ({0: 0.61, 1: 0.39}) - 111 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 5 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 4 instances
#    `- () - 63 instances
#       |- () - 59 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 3 instances
#       |  `- ({0: 0.12, 1: 0.88}) - 56 instances
#       `- ({0: 0.75, 1: 0.25}) - 4 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 167 instances
#    |  |- () - 165 instances
#    |  |  |- ({0: 0.38, 1: 0.62}) - 164 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 13 instances
#       |- () - 11 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#       |  `- ({0: 0.9, 1: 0.1}) - 10 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 114 instances
#    |  |- () - 111 instances
#    |  |  |- ({0: 0.6, 1: 0.4}) - 100 instances
#    |  |  `- ({0: 0.27, 1: 0.73}) - 11 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 3 instances
#    `- () - 66 instances
#       |- ({0: 1.0, 1: 0.0}) - 3 instances
#       `- () - 63 instances
#          |- ({0: 0.23, 1: 0.77}) - 62 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 72 instances
#    |  |- () - 71 instances
#    |  |  |- ({0: 0.17, 1: 0.83}) - 69 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 108 instances
#       |- ({0: 0.25, 1: 0.75}) - 4 instances
#       `- () - 104 instances
#          |- ({0: 0.61, 1: 0.39}) - 97 instances
#          `- ({0: 0.29, 1: 0.71}) - 7 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 75 instances
#    |  |- () - 74 instances
#    |  |  |- ({0: 0.16, 1: 0.84}) - 74 instances
#    |  |  `- ({0: 0.16, 1: 0.84}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 105 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 104 instances
#          |- ({0: 0.3, 1: 0.7}) - 10 instances
#          `- ({0: 0.66, 1: 0.34}) - 94 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 55 instances
#    |  |- () - 55 instances
#    |  |  |- ({0: 0.13, 1: 0.87}) - 54 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 0.15, 1: 0.85}) - 0 instances
#    `- () - 125 instances
#       |- () - 124 instances
#       |  |- ({0: 0.09, 1: 0.91}) - 11 instances
#       |  `- ({0: 0.66, 1: 0.34}) - 113 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 63 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- () - 61 instances
#    |     |- ({0: 0.21, 1: 0.79}) - 61 instances
#    |     `- ({0: 0.21, 1: 0.79}) - 0 instances
#    `- () - 117 instances
#       |- () - 66 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#       |  `- ({0: 0.77, 1: 0.23}) - 64 instances
#       `- () - 51 instances
#          |- ({0: 0.41, 1: 0.59}) - 49 instances
#          `- ({0: 1.0, 1: 0.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 174 instances
#    |  |- () - 172 instances
#    |  |  |- ({0: 0.6, 1: 0.4}) - 5 instances
#    |  |  `- ({0: 0.42, 1: 0.58}) - 167 instances
#    |  `- ({0: 0.5, 1: 0.5}) - 2 instances
#    `- () - 6 instances
#       |- ({0: 1.0, 1: 0.0}) - 5 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 150 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 4 instances
#    |  `- () - 146 instances
#    |     |- ({0: 0.34, 1: 0.66}) - 137 instances
#    |     `- ({0: 0.89, 1: 0.11}) - 9 instances
#    `- () - 30 instances
#       |- () - 30 instances
#       |  |- ({0: 0.86, 1: 0.14}) - 29 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.83, 1: 0.17}) - 0 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 16 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- () - 14 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 13 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 164 instances
#       |- () - 135 instances
#       |  |- ({0: 0.33, 1: 0.67}) - 116 instances
#       |  `- ({0: 0.68, 1: 0.32}) - 19 instances
#       `- () - 29 instances
#          |- ({0: 0.95, 1: 0.05}) - 21 instances
#          `- ({0: 0.0, 1: 1.0}) - 8 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 122 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- () - 120 instances
#    |     |- ({0: 0.67, 1: 0.33}) - 109 instances
#    |     `- ({0: 0.18, 1: 0.82}) - 11 instances
#    `- () - 58 instances
#       |- () - 58 instances
#       |  |- ({0: 0.17, 1: 0.83}) - 58 instances
#       |  `- ({0: 0.17, 1: 0.83}) - 0 instances
#       `- ({0: 0.17, 1: 0.83}) - 0 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 172 instances
#    |  |- () - 24 instances
#    |  |  |- ({0: 0.9, 1: 0.1}) - 20 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#    |  `- () - 148 instances
#    |     |- ({0: 0.6, 1: 0.4}) - 62 instances
#    |     `- ({0: 0.2, 1: 0.8}) - 86 instances
#    `- () - 8 instances
#       |- ({0: 1.0, 1: 0.0}) - 7 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 131 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 130 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 8 instances
#    |     `- ({0: 0.31, 1: 0.69}) - 122 instances
#    `- () - 49 instances
#       |- () - 42 instances
#       |  |- ({0: 0.78, 1: 0.22}) - 40 instances
#       |  `- ({0: 0.5, 1: 0.5}) - 2 instances
#       `- () - 7 instances
#          |- ({0: 0.17, 1: 0.83}) - 6 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 136 instances
#    |  |- () - 128 instances
#    |  |  |- ({0: 0.29, 1: 0.71}) - 126 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- () - 8 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 7 instances
#    `- () - 44 instances
#       |- () - 43 instances
#       |  |- ({0: 0.79, 1: 0.21}) - 43 instances
#       |  `- ({0: 0.79, 1: 0.21}) - 0 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 62 instances
#    |  |- () - 62 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  |  `- ({0: 0.13, 1: 0.87}) - 60 instances
#    |  `- ({0: 0.16, 1: 0.84}) - 0 instances
#    `- () - 118 instances
#       |- ({0: 0.0, 1: 1.0}) - 3 instances
#       `- () - 115 instances
#          |- ({0: 0.0, 1: 1.0}) - 1 instances
#          `- ({0: 0.61, 1: 0.39}) - 114 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 138 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 3 instances
#    |  `- () - 135 instances
#    |     |- ({0: 0.92, 1: 0.08}) - 13 instances
#    |     `- ({0: 0.3, 1: 0.7}) - 122 instances
#    `- () - 42 instances
#       |- () - 41 instances
#       |  |- ({0: 0.82, 1: 0.18}) - 38 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 3 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 20 instances
#    |  |- () - 19 instances
#    |  |  |- ({0: 0.88, 1: 0.12}) - 16 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 3 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 160 instances
#       |- () - 158 instances
#       |  |- ({0: 0.42, 1: 0.58}) - 152 instances
#       |  `- ({0: 0.67, 1: 0.33}) - 6 instances
#       `- ({0: 1.0, 1: 0.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 148 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 147 instances
#    |     |- ({0: 0.91, 1: 0.09}) - 11 instances
#    |     `- ({0: 0.3, 1: 0.7}) - 136 instances
#    `- () - 32 instances
#       |- () - 30 instances
#       |  |- ({0: 0.97, 1: 0.03}) - 29 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 17 instances
#    |  |- () - 16 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 15 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 163 instances
#       |- () - 5 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 4 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 158 instances
#          |- ({0: 0.36, 1: 0.64}) - 151 instances
#          `- ({0: 0.71, 1: 0.29}) - 7 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 43 instances
#    |  |- () - 7 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 3 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#    |  `- () - 36 instances
#    |     |- ({0: 0.82, 1: 0.18}) - 28 instances
#    |     `- ({0: 0.38, 1: 0.62}) - 8 instances
#    `- () - 137 instances
#       |- () - 14 instances
#       |  |- ({0: 0.83, 1: 0.17}) - 12 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#       `- () - 123 instances
#          |- ({0: 0.33, 1: 0.67}) - 122 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 171 instances
#    |  |- () - 153 instances
#    |  |  |- ({0: 0.36, 1: 0.64}) - 150 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 3 instances
#    |  `- () - 18 instances
#    |     |- ({0: 0.88, 1: 0.12}) - 16 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 2 instances
#    `- () - 9 instances
#       |- () - 8 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 7 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 27 instances
#    |  |- () - 26 instances
#    |  |  |- ({0: 0.96, 1: 0.04}) - 25 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 153 instances
#       |- ({0: 1.0, 1: 0.0}) - 2 instances
#       `- () - 151 instances
#          |- ({0: 0.37, 1: 0.63}) - 150 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 82 instances
#    |  |- () - 10 instances
#    |  |  |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 8 instances
#    |  `- () - 72 instances
#    |     |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |     `- ({0: 0.23, 1: 0.77}) - 71 instances
#    `- () - 98 instances
#       |- () - 96 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 5 instances
#       |  `- ({0: 0.63, 1: 0.37}) - 91 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 161 instances
#    |  |- () - 160 instances
#    |  |  |- ({0: 0.41, 1: 0.59}) - 148 instances
#    |  |  `- ({0: 0.67, 1: 0.33}) - 12 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 19 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 18 instances
#          |- ({0: 0.88, 1: 0.12}) - 16 instances
#          `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 136 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 135 instances
#    |     |- ({0: 0.15, 1: 0.85}) - 66 instances
#    |     `- ({0: 0.59, 1: 0.41}) - 69 instances
#    `- () - 44 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 43 instances
#          |- ({0: 0.33, 1: 0.67}) - 9 instances
#          `- ({0: 0.76, 1: 0.24}) - 34 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 167 instances
#    |  |- () - 159 instances
#    |  |  |- ({0: 0.75, 1: 0.25}) - 20 instances
#    |  |  `- ({0: 0.37, 1: 0.63}) - 139 instances
#    |  `- () - 8 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |     `- ({0: 0.86, 1: 0.14}) - 7 instances
#    `- () - 13 instances
#       |- () - 12 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 11 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 26 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 20 instances
#    |  `- () - 6 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 3 instances
#    |     `- ({0: 0.67, 1: 0.33}) - 3 instances
#    `- () - 154 instances
#       |- () - 141 instances
#       |  |- ({0: 0.31, 1: 0.69}) - 126 instances
#       |  `- ({0: 0.67, 1: 0.33}) - 15 instances
#       `- () - 13 instances
#          |- ({0: 1.0, 1: 0.0}) - 12 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 74 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 73 instances
#    |     |- ({0: 0.68, 1: 0.32}) - 72 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 106 instances
#       |- () - 99 instances
#       |  |- ({0: 0.27, 1: 0.73}) - 94 instances
#       |  `- ({0: 0.6, 1: 0.4}) - 5 instances
#       `- () - 7 instances
#          |- ({0: 0.83, 1: 0.17}) - 6 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 73 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 72 instances
#    |     |- ({0: 0.76, 1: 0.24}) - 70 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 2 instances
#    `- () - 107 instances
#       |- ({0: 1.0, 1: 0.0}) - 1 instances
#       `- () - 106 instances
#          |- ({0: 0.21, 1: 0.79}) - 103 instances
#          `- ({0: 1.0, 1: 0.0}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 123 instances
#    |  |- () - 115 instances
#    |  |  |- ({0: 0.63, 1: 0.37}) - 104 instances
#    |  |  `- ({0: 0.18, 1: 0.82}) - 11 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 8 instances
#    `- () - 57 instances
#       |- () - 9 instances
#       |  |- ({0: 0.0, 1: 1.0}) - 3 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 6 instances
#       `- () - 48 instances
#          |- ({0: 0.67, 1: 0.33}) - 6 instances
#          `- ({0: 0.19, 1: 0.81}) - 42 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 112 instances
#    |  |- () - 64 instances
#    |  |  |- ({0: 0.69, 1: 0.31}) - 62 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 2 instances
#    |  `- () - 48 instances
#    |     |- ({0: 0.36, 1: 0.64}) - 45 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 3 instances
#    `- () - 68 instances
#       |- ({0: 1.0, 1: 0.0}) - 4 instances
#       `- () - 64 instances
#          |- ({0: 0.19, 1: 0.81}) - 64 instances
#          `- ({0: 0.19, 1: 0.81}) - 0 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 171 instances
#    |  |- () - 139 instances
#    |  |  |- ({0: 0.32, 1: 0.68}) - 129 instances
#    |  |  `- ({0: 0.7, 1: 0.3}) - 10 instances
#    |  `- () - 32 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |     `- ({0: 0.87, 1: 0.13}) - 30 instances
#    `- () - 9 instances
#       |- () - 8 instances
#       |  |- ({0: 1.0, 1: 0.0}) - 7 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 70 instances
#    |  |- () - 69 instances
#    |  |  |- ({0: 0.19, 1: 0.81}) - 67 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 110 instances
#       |- () - 108 instances
#       |  |- ({0: 0.33, 1: 0.67}) - 3 instances
#       |  `- ({0: 0.62, 1: 0.38}) - 105 instances
#       `- ({0: 0.0, 1: 1.0}) - 2 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 136 instances
#    |  |- () - 131 instances
#    |  |  |- ({0: 0.82, 1: 0.18}) - 11 instances
#    |  |  `- ({0: 0.31, 1: 0.69}) - 120 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 5 instances
#    `- () - 44 instances
#       |- () - 41 instances
#       |  |- ({0: 0.76, 1: 0.24}) - 34 instances
#       |  `- ({0: 0.29, 1: 0.71}) - 7 instances
#       `- ({0: 0.33, 1: 0.67}) - 3 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 108 instances
#    |  |- () - 107 instances
#    |  |  |- ({0: 0.3, 1: 0.7}) - 107 instances
#    |  |  `- ({0: 0.3, 1: 0.7}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 72 instances
#       |- ({0: 0.0, 1: 1.0}) - 2 instances
#       `- () - 70 instances
#          |- ({0: 0.65, 1: 0.35}) - 69 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 132 instances
#    |  |- () - 116 instances
#    |  |  |- ({0: 0.67, 1: 0.33}) - 104 instances
#    |  |  `- ({0: 0.25, 1: 0.75}) - 12 instances
#    |  `- () - 16 instances
#    |     |- ({0: 0.27, 1: 0.73}) - 15 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 48 instances
#       |- () - 47 instances
#       |  |- ({0: 0.15, 1: 0.85}) - 47 instances
#       |  `- ({0: 0.15, 1: 0.85}) - 0 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 47 instances
#    |  |- () - 5 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 4 instances
#    |  `- () - 42 instances
#    |     |- ({0: 0.0, 1: 1.0}) - 2 instances
#    |     `- ({0: 0.65, 1: 0.35}) - 40 instances
#    `- () - 133 instances
#       |- ({0: 1.0, 1: 0.0}) - 1 instances
#       `- () - 132 instances
#          |- ({0: 0.38, 1: 0.62}) - 119 instances
#          `- ({0: 0.69, 1: 0.31}) - 13 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 111 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 4 instances
#    |  `- () - 107 instances
#    |     |- ({0: 0.38, 1: 0.62}) - 53 instances
#    |     `- ({0: 0.7, 1: 0.3}) - 54 instances
#    `- () - 69 instances
#       |- () - 60 instances
#       |  |- ({0: 0.27, 1: 0.73}) - 60 instances
#       |  `- ({0: 0.27, 1: 0.73}) - 0 instances
#       `- () - 9 instances
#          |- ({0: 0.88, 1: 0.12}) - 8 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 59 instances
#    |  |- () - 56 instances
#    |  |  |- ({0: 0.16, 1: 0.84}) - 55 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- ({0: 0.67, 1: 0.33}) - 3 instances
#    `- () - 121 instances
#       |- () - 104 instances
#       |  |- ({0: 0.64, 1: 0.36}) - 96 instances
#       |  `- ({0: 0.12, 1: 0.88}) - 8 instances
#       `- () - 17 instances
#          |- ({0: 0.31, 1: 0.69}) - 16 instances
#          `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 117 instances
#    |  |- () - 117 instances
#    |  |  |- ({0: 0.65, 1: 0.35}) - 116 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.64, 1: 0.36}) - 0 instances
#    `- () - 63 instances
#       |- () - 62 instances
#       |  |- ({0: 0.1, 1: 0.9}) - 0 instances
#       |  `- ({0: 0.1, 1: 0.9}) - 62 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 149 instances
#    |  |- () - 148 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  |  `- ({0: 0.38, 1: 0.62}) - 146 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 31 instances
#       |- () - 30 instances
#       |  |- ({0: 0.83, 1: 0.17}) - 29 instances
#       |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 138 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 2 instances
#    |  `- () - 136 instances
#    |     |- ({0: 0.34, 1: 0.66}) - 135 instances
#    |     `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 42 instances
#       |- () - 41 instances
#       |  |- ({0: 0.84, 1: 0.16}) - 37 instances
#       |  `- ({0: 0.25, 1: 0.75}) - 4 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 157 instances
#    |  |- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 156 instances
#    |     |- ({0: 0.67, 1: 0.33}) - 30 instances
#    |     `- ({0: 0.35, 1: 0.65}) - 126 instances
#    `- () - 23 instances
#       |- ({0: 0.0, 1: 1.0}) - 1 instances
#       `- () - 22 instances
#          |- ({0: 0.81, 1: 0.19}) - 21 instances
#          `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 9 instances
#    |  |- () - 8 instances
#    |  |  |- ({0: 1.0, 1: 0.0}) - 7 instances
#    |  |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 171 instances
#       |- () - 145 instances
#       |  |- ({0: 0.37, 1: 0.63}) - 137 instances
#       |  `- ({0: 0.75, 1: 0.25}) - 8 instances
#       `- () - 26 instances
#          |- ({0: 0.67, 1: 0.33}) - 21 instances
#          `- ({0: 0.2, 1: 0.8}) - 5 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 106 instances
#    |  |- () - 7 instances
#    |  |  |- ({0: 0.17, 1: 0.83}) - 6 instances
#    |  |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    |  `- () - 99 instances
#    |     |- ({0: 0.65, 1: 0.35}) - 98 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 74 instances
#       |- ({0: 1.0, 1: 0.0}) - 1 instances
#       `- () - 73 instances
#          |- ({0: 1.0, 1: 0.0}) - 1 instances
#          `- ({0: 0.24, 1: 0.76}) - 72 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 27 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 26 instances
#    |     |- ({0: 0.69, 1: 0.31}) - 0 instances
#    |     `- ({0: 0.69, 1: 0.31}) - 26 instances
#    `- () - 153 instances
#       |- ({0: 1.0, 1: 0.0}) - 2 instances
#       `- () - 151 instances
#          |- ({0: 0.33, 1: 0.67}) - 116 instances
#          `- ({0: 0.69, 1: 0.31}) - 35 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 40 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 39 instances
#    |     |- ({0: 0.82, 1: 0.18}) - 0 instances
#    |     `- ({0: 0.82, 1: 0.18}) - 39 instances
#    `- () - 140 instances
#       |- () - 139 instances
#       |  |- ({0: 0.36, 1: 0.64}) - 136 instances
#       |  `- ({0: 1.0, 1: 0.0}) - 3 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 69 instances
#    |  |- () - 67 instances
#    |  |  |- ({0: 0.19, 1: 0.81}) - 62 instances
#    |  |  `- ({0: 0.8, 1: 0.2}) - 5 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 2 instances
#    `- () - 111 instances
#       |- () - 110 instances
#       |  |- ({0: 0.67, 1: 0.33}) - 3 instances
#       |  `- ({0: 0.58, 1: 0.42}) - 107 instances
#       `- ({0: 0.0, 1: 1.0}) - 1 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 65 instances
#    |  |- () - 64 instances
#    |  |  |- ({0: 0.22, 1: 0.78}) - 64 instances
#    |  |  `- ({0: 0.22, 1: 0.78}) - 0 instances
#    |  `- ({0: 1.0, 1: 0.0}) - 1 instances
#    `- () - 115 instances
#       |- ({0: 0.0, 1: 1.0}) - 2 instances
#       `- () - 113 instances
#          |- ({0: 0.62, 1: 0.38}) - 106 instances
#          `- ({0: 0.43, 1: 0.57}) - 7 instances
#
#  ----------------------------------------
#
# `- () - 180 instances
#    |- () - 28 instances
#    |  |- ({0: 0.0, 1: 1.0}) - 1 instances
#    |  `- () - 27 instances
#    |     |- ({0: 0.88, 1: 0.12}) - 26 instances
#    |     `- ({0: 0.0, 1: 1.0}) - 1 instances
#    `- () - 152 instances
#       |- () - 151 instances
#       |  |- ({0: 0.56, 1: 0.44}) - 16 instances
#       |  `- ({0: 0.34, 1: 0.66}) - 135 instances
#       `- ({0: 1.0, 1: 0.0}) - 1 instances

# %%
corr_dict = qrf.compute_tree_correlation()
for k,v in corr_dict.items():
    print("Class", k)
    plt.imshow(v)
    plt.colorbar()
    plt.show()
# Out:
# Class 0
# Class 1
